# %%
import cv2
from matplotlib import pyplot as plt
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from util.caltech_dataset import caltech_dataset
from util.augmentation import RandomFlip, RandomCrop


augmentation_methods = [
    RandomFlip(prob=0.5),
    RandomCrop(crop_rate=0.1, prob=1.0),
]
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
train_dataset = caltech_dataset(
        data_dir="/media/hdd2/labeled_pairs/", split='train', transform=augmentation_methods)

image,thermal,label,names = train_dataset.__getitem__(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/miniconda3/lib/python3.11/site-packages/PIL/Image.py:3070, in fromarray(obj, mode)
#    3069 try:
# -> 3070     mode, rawmode = _fromarray_typemap[typekey]
#    3071 except KeyError as e:
#
# KeyError: ((1, 1, 3), '<f8')
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       1 train_dataset = caltech_dataset(
#       2         data_dir="/media/hdd2/labeled_pairs/", split='train', transform=augmentation_methods)
# ----> 4 image,thermal,label,names = train_dataset.__getitem__(3)
#
# File ~/third_party/EAEFNet/EAEF_Seg_PST/Caltech/util/caltech_dataset.py:88, in caltech_dataset.__getitem__(self, index)
#      62 label = self.read_image(
#      63     rgb_name_list[1], 'annotations')
# ...

# %%
plt.figure()
plt.imshow(image.numpy().transpose((1,2,0)).astype(float))

plt.figure()
plt.imshow(thermal.numpy().transpose((1,2,0)).astype(float))

plt.figure()
label_scl = label * 255/10
plt.imshow(label_scl.numpy().astype(int))
